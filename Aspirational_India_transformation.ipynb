# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_excel('./CMIE_Data/CMIE_Aspirational_India.xlsx', '2021-0901')
df2 = pd.read_excel('./CMIE_Data/CMIE_Aspirational_India.xlsx', '2020-0501')
df3 = pd.read_excel('./CMIE_Data/CMIE_Aspirational_India.xlsx', '2019-0101')
df4 = pd.read_excel('./CMIE_Data/CMIE_Aspirational_India.xlsx', '2018-0901')
df5 = pd.read_excel('./CMIE_Data/CMIE_Aspirational_India.xlsx', '2017-0901')
df6 = pd.read_excel('./CMIE_Data/CMIE_Aspirational_India.xlsx', '2017-0501')
df7 = pd.read_excel('./CMIE_Data/CMIE_Aspirational_India.xlsx', '2017-0101')

# %%
df5['HH_ID'].equals(df6['HH_ID'])
# Out:
# False

# %%
df6.loc[~df6['HH_ID'].isin(df1['HH_ID'].tolist())]
# Out:
#      WAVE_NO     HH_ID        STATE     HR           DISTRICT REGION_TYPE  \
# 2         11  94992536  West Bengal  HR 87  South 24 Parganas       URBAN
# 5         11  51955731  West Bengal  HR 87  South 24 Parganas       URBAN
# 12        11  18797020  West Bengal  HR 87  South 24 Parganas       URBAN
# 13        11  92361105  West Bengal  HR 87  South 24 Parganas       URBAN
# 15        11  37161775  West Bengal  HR 87  South 24 Parganas       URBAN
# ..       ...       ...          ...    ...                ...         ...
# 634       11  40372059  West Bengal  HR 87  South 24 Parganas       URBAN
# 643       11  25151331  West Bengal  HR 87  South 24 Parganas       URBAN
# 648       11  32136454  West Bengal  HR 87  South 24 Parganas       URBAN
# 774       11  83417542  West Bengal  HR 87  South 24 Parganas       RURAL
# 788       11  11192599  West Bengal  HR 87  South 24 Parganas       RURAL
#
#            STRATUM        PSU_ID  MONTH_SLOT RESPONSE_STATUS  ...  \
# ...

# %%
df1.loc[~df1['HH_ID'].isin(df6['HH_ID'].tolist())]
# Out:
#      WAVE_NO     HH_ID        STATE     HR           DISTRICT REGION_TYPE  \
# 251       24  53125386  West Bengal  HR 87  South 24 Parganas       URBAN
# 252       24  34939670  West Bengal  HR 87  South 24 Parganas       URBAN
# 504       24  10863162  West Bengal  HR 87  South 24 Parganas       URBAN
# 632       24  22169350  West Bengal  HR 87  South 24 Parganas       RURAL
#
#            STRATUM        PSU_ID  MONTH_SLOT RESPONSE_STATUS  ...  \
# 251  HR 87_URBAN_L   PSU_ID_6708       44501    Non-Response  ...
# 252  HR 87_URBAN_L   PSU_ID_6708       44501        Accepted  ...
# 504  HR 87_URBAN_S   PSU_ID_6711       44531    Non-Response  ...
# 632  HR 87_RURAL_R  PSU_ID_10598       44470    Non-Response  ...
#
#     IS_THIS_GOOD_TIME_TO_BUY_CONSUMER_DURABLES  \
# 251                         Data Not Available
# 252                        Same as other times
# 504                         Data Not Available
# 632                         Data Not Available
#
# ...

# %%
df6 = df6.drop(labels=df6.loc[~df6['HH_ID'].isin(df1['HH_ID'].tolist())].index)

# %%
df7 = df7.drop(labels=df7.loc[~df7['HH_ID'].isin(df1['HH_ID'].tolist())].index)

# %%
df1 = df1.drop(labels=df1.loc[~df1['HH_ID'].isin(df6['HH_ID'].tolist())].index)

# %%
df2 = df2.drop(labels=df2.loc[~df2['HH_ID'].isin(df6['HH_ID'].tolist())].index)

# %%
df3 = df3.drop(labels=df3.loc[~df3['HH_ID'].isin(df6['HH_ID'].tolist())].index)

# %%
df4 = df4.drop(labels=df4.loc[~df4['HH_ID'].isin(df6['HH_ID'].tolist())].index)

# %%
df5 = df5.drop(labels=df5.loc[~df5['HH_ID'].isin(df6['HH_ID'].tolist())].index)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756 entries, 0 to 911
# Columns: 284 entries, WAVE_NO to TIME_TO_TRAVEL_TEN_KMS
# dtypes: float64(6), int64(19), object(259)
# memory usage: 1.6+ MB

# %%
df6.loc[~df6['HH_ID'].isin(df1['HH_ID'].tolist())]
# Out:
# Empty DataFrame
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756 entries, 0 to 759
# Columns: 300 entries, WAVE_NO to TIME_TO_TRAVEL_TEN_KMS
# dtypes: float64(6), int64(19), object(275)
# memory usage: 1.7+ MB

# %% [markdown]
# df1.info()

# %%
df2.to_excel('2020-0501.xlsx')
df3.to_excel('2019-0101.xlsx')
df4.to_excel('2018-0901.xlsx')
df5.to_excel('2017-0901.xlsx')
df6.to_excel('2017-0501.xlsx')
df7.to_excel('2017-0101.xlsx')
df1.to_excel('2021-0901.xlsx')
